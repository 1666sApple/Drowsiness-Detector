# %%
import torch
import numpy as np
import pandas as pd
import ultralytics
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
# Out:
# /tmp/ipykernel_6291/1166667504.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# Setup complete ✅ (16 CPUs, 15.0 GB RAM, 60.8/147.9 GB disk)

# %%
# capture = cv2.VideoCapture(0) # for video capture = cv2.VideoCapture('videofilename.format')

# while capture.isOpened():
#     ret, frame = capture.read()

#     # Make Detection
#     results = model(frame)

#     cv2.imshow('YOLO', np.squeeze(results.render()))

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# capture.release()
# cv2.destroyAllWindows()

# %%
yolov8 = YOLO("yolov8n.pt")

# %%
yolov8
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model 

results = model.train(data='data.yaml', batch=2, epochs=50, imgsz=640, workers=1)
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.12 🚀 Python-3.12.2 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
model = YOLO('runs/detect/train7/weights/best.pt')

# %%
# # Load a model for inference
# inference_model = YOLO('runs/detect/train7/weights/best.pt')

# # Start video capture
# capture = cv2.VideoCapture(0)

# while capture.isOpened():
#     ret, frame = capture.read()
    
#     # Perform object detection on the frame
#     detections = inference_model(frame)
    
#     # Show the detections on the frame
#     cv2.imshow('YOLO', np.squeeze(detections.render()))
    
#     # Wait for 'q' key to quit
#     if cv2.waitKey(10) & 0xFF == ord('q'):
#         break

# # Release video capture resource and close OpenCV windows
# capture.release()
# cv2.destroyAllWindows()

# %%
# capture = cv2.VideoCapture(0)
# while capture.isOpened():
#     ret, frame = capture.read()
    
#     # Make detections 
#     results = model(frame)
    
#     cv2.imshow('YOLO', np.squeeze(results.render()))
    
#     if cv2.waitKey(10) & 0xFF == ord('q'):
#         break
# capture.release()
# cv2.destroyAllWindows()

# %%
import cv2

model.predict(source = "0", show = True, conf = 0.5)
# Out:
# ...
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 290.8ms
# 0: 480x640 (no detections), 6.1ms
# 0: 480x640 (no detections), 5.5ms
# 0: 480x640 (no detections), 6.0ms
# WARNING ⚠️ Waiting for stream 0
# 0: 480x640 (no detections), 4.8ms
# 0: 480x640 (no detections), 5.1ms
# WARNING ⚠️ Waiting for stream 0
# 0: 480x640 (no detections), 6.1ms
# 0: 480x640 (no detections), 5.3ms
# ...

# %%
from yolov5.detect import Detect
import cv2

# Initialize the YOLOv5 detector
detector = Detect(weights='yolov5s.pt')

# Start video capture
capture = cv2.VideoCapture(0)

while capture.isOpened():
    ret, frame = capture.read()
    
    # Perform inference on the frame
    results = detector(frame)
    
    # Show the detections
    results.show()

    # Wait for the user to press 'q' to quit
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release video capture resource and close all OpenCV windows
capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from yolov5.detect import Detect
#       2 import cv2
#       4 # Initialize the YOLOv5 detector
#
# ImportError: cannot import name 'Detect' from 'yolov5.detect' (/home/i666sapple/.local/lib/python3.12/site-packages/yolov5/detect.py)

# %%
img = cv2.imread('Dataset/Drowsy/303.jpg')

# img = cv2.imshow('Image', img)

# %%
results = model(img)
# Out:
# 0: 480x640 1 Drowsy, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 36.5ms postprocess per image at shape (1, 3, 480, 640)

# %%
results.print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 results.print()
#
# AttributeError: 'list' object has no attribute 'print'

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 plt.imshow(np.squeeze(results.render()))
#       3 plt.show()
#
# AttributeError: 'list' object has no attribute 'render'
